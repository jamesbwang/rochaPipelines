# %%
import pandas as pd
import sys
path = "chr8_Clusters.tsv"

# %%
df = pd.read_csv(path, sep="\t", names=["chr", "RI", "startBin", "endBin", "insulation"])

# %%
df = df[df["RI"] >=.700]

# %%
df
# Out:
#           chr     RI  startBin  endBin  insulation
# 4286441  chr8  0.701         6       7         NaN
# 4286442  chr8  0.701         8       9         NaN
# 4286443  chr8  0.701        10      11         NaN
# 4286444  chr8  0.701        12      13         NaN
# 4286445  chr8  0.701        14      15         NaN
# 4286446  chr8  0.701        16      17         NaN
# 4286447  chr8  0.701        18      19         NaN
# 4286448  chr8  0.701        20      21    1.000000
# 4286449  chr8  0.701        22     339    0.706543
# 4286450  chr8  0.701       340     359    0.708979
# 4286451  chr8  0.701       360     398    0.813581
# 4286452  chr8  0.701       399     437    0.727809
# 4286453  chr8  0.701       438     473    0.751332
# 4286454  chr8  0.701       474     535    0.723460
# 4286455  chr8  0.701       536     565    0.715957
# 4286456  chr8  0.701       566     618    0.769736
# 4286457  chr8  0.701       619     696    0.746769
# ...

# %%
df.to_csv(path + ".bed", sep="\t", header=False, index=False)
