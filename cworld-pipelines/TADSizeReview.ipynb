# %%
import matplotlib.pyplot as plt

import pandas as pd
import sys

# %%
bedpe = "../tmp/inter_2.hic.sorted.bedpe"

# %%
df = pd.read_csv(bedpe, names=["chr1", "start1", "end1", "chr2", "start2", "end2"], index_col=False, sep="\t", usecols=["chr1", "start1", "end1"])

# %%
df["sizes"] = df["end1"] - df["start1"]

# %%
fig = plt.figure()
plt.hist(df["sizes"], bins=200)
plt.xlabel("region size")
plt.ylabel("# TADS")
# Out:
# Text(0, 0.5, '# TADS')

# %%
fig.savefig(bedpe.split("/")[-1] + ".png")

# %%
# Out:
#        chr1     start1       end1   sizes
# 0      chr1      50000     135000   85000
# 1      chr1     140000     145000    5000
# 2      chr1     150000     155000    5000
# 3      chr1     160000     165000    5000
# 4      chr1     170000     175000    5000
# 5      chr1     180000     185000    5000
# 6      chr1     190000     195000    5000
# 7      chr1     200000     205000    5000
# 8      chr1     210000     215000    5000
# 9      chr1     220000     255000   35000
# 10     chr1     260000     265000    5000
# 11     chr1     270000     275000    5000
# 12     chr1     280000     285000    5000
# 13     chr1     290000     295000    5000
# 14     chr1     300000     305000    5000
# 15     chr1     310000     315000    5000
# 16     chr1     320000     325000    5000
# 17     chr1     330000     335000    5000
# 18     chr1     340000     345000    5000
# 19     chr1     350000     355000    5000
# 20     chr1     360000     365000    5000
# 21     chr1     370000     375000    5000
# 22     chr1     380000     385000    5000
# 23     chr1     390000     395000    5000
# 24     chr1     400000     405000    5000
# 25     chr1     410000     415000    5000
# 26     chr1     420000     425000    5000
# 27     chr1     430000     435000    5000
# 28     chr1     440000     445000    5000
# 29     chr1     450000     455000    5000
# ...     ...        ...        ...     ...
# 37718  chr9  139210000  139365000  155000
# 37719  chr9  139210000  139565000  355000
# 37720  chr9  139210000  139580000  370000
# 37721  chr9  139210000  139595000  385000
# 37722  chr9  139210000  139610000  400000
# 37723  chr9  139210000  139620000  410000
# 37724  chr9  139210000  139625000  415000
# 37725  chr9  139370000  139535000  165000
# 37726  chr9  139370000  139550000  180000
# 37727  chr9  139540000  139650000  110000
# 37728  chr9  139555000  140145000  590000
# 37729  chr9  139570000  140145000  575000
# 37730  chr9  139585000  140145000  560000
# 37731  chr9  139600000  140145000  545000
# 37732  chr9  139615000  140145000  530000
# 37733  chr9  139625000  140145000  520000
# 37734  chr9  139630000  140145000  515000
# 37735  chr9  139655000  139935000  280000
# 37736  chr9  139655000  140145000  490000
# 37737  chr9  139940000  140145000  205000
# 37738  chr9  140150000  140420000  270000
# 37739  chr9  140150000  140435000  285000
# 37740  chr9  140150000  140440000  290000
# 37741  chr9  140150000  141115000  965000
# 37742  chr9  140425000  140515000   90000
# 37743  chr9  140440000  141115000  675000
# 37744  chr9  140445000  141115000  670000
# 37745  chr9  140520000  140735000  215000
# 37746  chr9  140520000  141115000  595000
# 37747  chr9  140740000  141115000  375000
#
# [37748 rows x 4 columns]
